# %% [markdown]
# ## Importing the required modules to be used

# %%
import pandas as pd
import numpy as np
import xlrd

# %% [markdown]
# ## using the xlrd and pandas modules to read the excel data into the pandas dataFrame

# %%
df = pd.read_excel('Superstore.xls')

# %% [markdown]
# ## Getting a quick general information about the data to be analyzed.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %% [markdown]
# ## Retreiving and having a quick look the first 15 records of the dataset

# %%
df.head(15)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1        2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2        3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3        4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4        5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 5        6  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 6        7  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 7        8  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 8        9  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 9       10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# 10      11  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# ## Retreiving and having a quick look at the last 15 records of the dataset.

# %%
df.tail(15)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9979    9980  US-2020-103674 2020-12-06 2020-12-10  Standard Class
# 9980    9981  US-2019-151435 2019-09-06 2019-09-09    Second Class
# 9981    9982  CA-2021-163566 2021-08-03 2021-08-06     First Class
# 9982    9983  US-2020-157728 2020-09-22 2020-09-28  Standard Class
# 9983    9984  US-2020-157728 2020-09-22 2020-09-28  Standard Class
# 9984    9985  CA-2019-100251 2019-05-17 2019-05-23  Standard Class
# 9985    9986  CA-2019-100251 2019-05-17 2019-05-23  Standard Class
# 9986    9987  CA-2020-125794 2020-09-29 2020-10-03  Standard Class
# 9987    9988  CA-2021-163629 2021-11-17 2021-11-21  Standard Class
# 9988    9989  CA-2021-163629 2021-11-17 2021-11-21  Standard Class
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# ...

# %% [markdown]
# ## Getting to know the data further i.e knowing the actual number of columns in the whole dataset using the len() function.

# %%
NumberOfColumns = len(df.columns)
print(NumberOfColumns)
# Out:
# 21

# %% [markdown]
# ## Getting to know the column names(header row names) of the data

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## getting to know the datatypes of each column(header row) in the data.

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [markdown]
# ## getting to know the number of rows in the whole dataset(i.e each index is a row/record in the dataset) by using the len() function.

# %%
NumberOfRows = len(df.index)
print(NumberOfRows)
# Out:
# 9994

# %% [markdown]
# ## getting to know how the indexes(rows) are arranged in the whole dataset.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# ## getting a quick preview of how may rows & columns are in the whole dataset by using the '.shape' object.

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# ## getting to know the actual size of the whole dataset

# %%
df.size
# Out:
# 209874

# %% [markdown]
# ## getting to know extra information i.e how many dimensions the whole dataset has.

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## gettin a quick statistical desciption of the whole dataset by each individual column.

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ## checking to know if the dataset is empty or not i.e i personally think this is a good practice and probably should be amongst the first steps of the dataset analysis right after reading the data into the pandas dataframe/series.

# %%
if df.empty:
    print('DataFrame is empty, do not proceed with the analysis')
else:
    print('You are good to go, proceed!')
# Out:
# You are good to go, proceed!

# %% [markdown]
# ## checking to know if the dataset has any null or empty values or not i.e i personally think this too is a good practice and probably should be amongst the first steps of the dataset analysis right after reading the data into the pandas dataframe/series.

# %%
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country/Region   City  ...  Postal Code  Region  \
# ...

# %% [markdown]
# ## getting to know the total number of empty values in each column i.e i personally think this is a good practice and probably should be amongst the first steps of the dataset analysis right after reading the data into the pandas dataframe/series.

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %% [markdown]
# ## Getting to know the non-empty values in the dataset i.e i personally think this is a good practice and probably should be amongst the first steps of the dataset analysis right after reading the data into the pandas dataframe/series.

# %%
df.notnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       True      True        True       True       True         True
# 1       True      True        True       True       True         True
# 2       True      True        True       True       True         True
# 3       True      True        True       True       True         True
# 4       True      True        True       True       True         True
# ...      ...       ...         ...        ...        ...          ...
# 9989    True      True        True       True       True         True
# 9990    True      True        True       True       True         True
# 9991    True      True        True       True       True         True
# 9992    True      True        True       True       True         True
# 9993    True      True        True       True       True         True
#
#       Customer Name  Segment  Country/Region  City  ...  Postal Code  Region  \
# ...

# %% [markdown]
# ## Getting to know the total number of non-empty values to work with in each column i.e i personally think this is a good practice and probably should be amongst the first steps of the dataset analysis right after reading the data into the pandas dataframe/series.

# %%
df.notnull().sum()
# Out:
# Row ID            9994
# Order ID          9994
# Order Date        9994
# Ship Date         9994
# Ship Mode         9994
# Customer ID       9994
# Customer Name     9994
# Segment           9994
# Country/Region    9994
# City              9994
# State             9994
# Postal Code       9983
# Region            9994
# Product ID        9994
# Category          9994
# Sub-Category      9994
# Product Name      9994
# Sales             9994
# Quantity          9994
# Discount          9994
# Profit            9994
# dtype: int64

# %% [markdown]
# ## getting the percentage of the total number of missing values in each column of the dataset.

# %%
percentage_missing = df.isnull().sum() * 100 / len(df)
missing_values = {'column_name': df.columns,
                                            'percentage_missing': percentage_missing}

# %%
print(missing_values, percentage_missing)
# Out:
# {'column_name': Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object'), 'percentage_missing': Row ID            0.000000
# Order ID          0.000000
# Order Date        0.000000
# Ship Date         0.000000
# Ship Mode         0.000000
# Customer ID       0.000000
# Customer Name     0.000000
# Segment           0.000000
# Country/Region    0.000000
# City              0.000000
# State             0.000000
# Postal Code       0.110066
# Region            0.000000
# Product ID        0.000000
# Category          0.000000
# Sub-Category      0.000000
# Product Name      0.000000
# Sales             0.000000
# Quantity          0.000000
# Discount          0.000000
# Profit            0.000000
# ...
